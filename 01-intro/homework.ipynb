# %%
# !curl -sL -O https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.6'

# %%
import numpy as np

df = pd.read_csv('car_fuel_efficiency_2026.csv')

# %% [markdown]
# ## Q2

# %%
df.shape
# Out:
# (10000, 11)

# %% [markdown]
# ## Q3

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %% [markdown]
# ## Q4

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# ## Q5

# %%
df[df['origin'] == 'Asia']['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %% [markdown]
# ## Q6

# %%
h = df['horsepower']
h.median()
# Out:
# np.float64(254.0)

# %%
most_frequent = h.mode().iloc[0]
h2 = h.fillna(most_frequent)
h2.median()
# Out:
# np.float64(252.0)

# %% [markdown]
# ## Q7

# %%
X = df[df['origin'] == 'Asia'][['vehicle_weight', 'model_year']].head(7).values
y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)

w = XTX_inv.dot(X.T.dot(y))
w.sum()
# Out:
# np.float64(0.3691969690492556)
